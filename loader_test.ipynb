# %%
import matplotlib.pyplot as plt

from torch.utils.data import  DataLoader
from pathlib import Path

from loader.dataset import SphericalProjectionKitti

def test_loader(loader, iter = 1):
    i = 0
    for data in loader:
        _, labels, proj_points, proj_labels, _  = data
        print(proj_points.shape, labels.shape, proj_labels.shape)
        plt.figure(figsize=(20,80))
        plt.imshow(proj_labels[0], cmap="gray")

        plt.figure(figsize=(20,80))
        plt.imshow(proj_points[0][2], cmap="gray")
        
        i+=1
        if i == iter:
            break

# %%
# !python3 preprocessing.py 

test_data = SphericalProjectionKitti(Path("examples/data/dataset_ready"), length=1)

test_loader_basic = DataLoader(test_data, batch_size=1, shuffle=False)

test_loader(test_loader_basic)
# Out:
# 100%|█████████████████████████████████████████████| 1/1 [00:00<00:00, 14.75it/s]
# torch.Size([1, 3, 64, 1024]) torch.Size([1, 124668]) torch.Size([1, 64, 1024])

# %%
# !python3 preprocessing.py --no_ransac
test_data = SphericalProjectionKitti(Path("examples/data/dataset_ready"), length=1)

test_loader_basic = DataLoader(test_data, batch_size=1, shuffle=False)

test_loader(test_loader_basic)
# Out:
# 100%|█████████████████████████████████████████████| 1/1 [00:00<00:00, 35.41it/s]
# torch.Size([1, 3, 64, 1024]) torch.Size([1, 124668]) torch.Size([1, 64, 1024])

# %%
# !python3 preprocessing.py --no_road
test_data = SphericalProjectionKitti(Path("examples/data/dataset_ready"), length=1)

test_loader_basic = DataLoader(test_data, batch_size=1, shuffle=False)

test_loader(test_loader_basic)
# Out:
# 100%|█████████████████████████████████████████████| 1/1 [00:00<00:00, 14.96it/s]
# torch.Size([1, 3, 64, 1024]) torch.Size([1, 124668]) torch.Size([1, 64, 1024])

# %%
# !python3 preprocessing.py --no_ransac --no_road
test_data = SphericalProjectionKitti(Path("examples/data/dataset_ready"), length=1)

test_loader_basic = DataLoader(test_data, batch_size=1, shuffle=False)

test_loader(test_loader_basic)
# Out:
# 100%|█████████████████████████████████████████████| 1/1 [00:00<00:00, 36.32it/s]
# torch.Size([1, 3, 64, 1024]) torch.Size([1, 124668]) torch.Size([1, 64, 1024])

# %%
test_data = SphericalProjectionKitti(Path("examples/data/dataset_ready"), length=1)

test_loader_basic = DataLoader(test_data, batch_size=1, shuffle=False)

test_loader(test_loader_basic)
# Out:
# torch.Size([1, 3, 64, 1024]) torch.Size([1, 124668]) torch.Size([1, 64, 1024])
